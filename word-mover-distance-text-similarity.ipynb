# %% [markdown]
# <a href="https://www.kaggle.com/abhishekraikaushik/word-mover-distance-text-similarity?scriptVersionId=88438961" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# Here is an example on how Text Similarity can be calucluted using WMD (http://radimrehurek.com/gensim/auto_examples/tutorials/run_wmd.html), which I think is helpful approach for this competition.

# %%
DATA_PATH = '../input/shopee-product-matching/'

import numpy as np 
import pandas as pd 
import gensim
from gensim.similarities import WmdSimilarity
from nltk.corpus import stopwords
from nltk import download
download('stopwords')  # Download stopwords list.
stop_words = stopwords.words('english')

train = pd.read_csv(DATA_PATH + 'train.csv')

## Google word embeddings

model = gensim.models.KeyedVectors.load_word2vec_format('../input/word2vecgooglenews300/GoogleNews-vectors-negative300.bin', binary=True)

## process raw titles
def preprocess(sentence):
    return [w for w in sentence.lower().split() if w not in stop_words]
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# ### > **Example using Shopee Data**

# %%
# Example using Shopee Data

raw_titles = train['title'].tolist()

neighbours = [ i for index,i in enumerate(raw_titles) if model.wmdistance(preprocess(raw_titles[579])
                                                        , preprocess(raw_titles[index])) <= 0.40]

# %%
raw_titles[579]
# Out:
# 'Sugar Baby Organic Healthy Cot Sheet Perlak Bayi'

# %%
## Not explicitly sorted based on distance  
neighbours
# Out:
# ['Sugar Baby Organic Healthy Cot Sheet Perlak Bayi',
#  'Sugar Baby Organic Healthy Cot Sheet - Perlak Karet',
#  'SUGAR BABY PREMIUM ORGANIC RUBBER COT SHEET PERLAK ONDO',
#  'Sugar Baby Perlak Bayi [90 x 60 CM] Organic Healthy Cot Sheet',
#  'Sugar Baby Perlak Organic Healthy Cot Sheet Motif ASOKA',
#  'Sugar Baby Perlak Ompol Bayi Karet Organic Healthy Cot Sheet',
#  'Sugar Baby Organic Healthy Premium Rubber Cot Sheet Perlak']
